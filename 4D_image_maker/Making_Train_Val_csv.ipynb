# %% [markdown]
# * Get a list of niftis
# * randomize them and put 100 for validation
# * Make the csv of each
# * Save them

# %%
import numpy as np
import os
import matplotlib.pyplot as plt
import nibabel as nib
import pandas as pd
from shutil import copy  
np.random.seed(12345)

# %% [markdown]
# ## ONLY Nature 3

# %%
train_folder = 'E:/data/Histology/Nature_4D_Organized/TrainValTest/OnlyNature3'
val_folder =   'E:/data/Histology/Nature_4D_Organized/TrainValTest/OnlyNature3'
test_folder =  'E:/data/Histology/Nature_4D_Organized/TrainValTest/OnlyNature3'
os.makedirs(train_folder, exist_ok=True)
os.makedirs(val_folder, exist_ok=True)
os.makedirs(test_folder, exist_ok=True)


nature_train = ['TCGA LUAD/LUSC','NSCLC Radiomics','NSCLC Radiomics-Genomics']
nature_val = ['Stanford','NSCLC Radiogenomics']
nature_test = [] #['NSCLC Radiogenomics'] #Sandys

df = pd.read_csv('both.csv')
df_train = pd.DataFrame(columns=['ID', 'Histology','Histology012'])
df_val   = pd.DataFrame(columns=['ID', 'Histology','Histology012'])
df_test  = pd.DataFrame(columns=['ID', 'Histology','Histology012'])

D = {'adenocarcinoma'              : 0 ,
     'Adenocarcinoma'              : 0 ,
     'Squamous cell carcinoma'     : 1 ,
     'squamous cell carcinoma'     : 1 ,
     'Sarcomatoid carcinoma'       : 2 ,
     'Adenosquamous carcinoma'     : 2 ,
     'Large cell carcinoma'        : 2 ,
     'Non-small cell carcinoma NOS': 2 ,
     'Sarcomatoid carcinoma'       : 2 ,
     'large cell'                  : 2 ,
     'nos'                         : 2 }

for i, id in enumerate(df['ID'].tolist()):
    id_i,patient_i,dataset_i, histology_i,_,Cohort_i = df.iloc[i].tolist()
    
    if dataset_i in nature_train:
        df_train = df_train.append([pd.Series([patient_i, histology_i, D[histology_i]], index = df_train.columns[0:3])], ignore_index=True)
        
    elif dataset_i in nature_val:
        df_val = df_val.append([pd.Series([patient_i, histology_i, D[histology_i]], index = df_val.columns[0:3])], ignore_index=True)

    elif dataset_i in nature_test:
        df_test = df_test.append([pd.Series([patient_i, histology_i, D[histology_i]], index = df_test.columns[0:3])], ignore_index=True)
        
    else:
        print(id_i,patient_i,dataset_i, histology_i,Cohort_i)
df_train.to_csv(os.path.join(train_folder, 'train.csv'))
df_val.to_csv(os.path.join(val_folder, 'val.csv'))
df_test.to_csv(os.path.join(test_folder, 'test.csv'))
# Out:
# 831 Patient_0002 Driver-negative Adenocarcinoma train
# 832 Patient_0007 Driver-negative Adenocarcinoma train
# 833 Patient_0008 Driver-negative Adenocarcinoma train
# 834 Patient_0009 Driver-negative Adenocarcinoma train
# 835 Patient_0010 Driver-negative Adenocarcinoma test
# 836 Patient_0011 Driver-negative Adenocarcinoma train
# 837 Patient_0012 Driver-negative Adenocarcinoma train
# 838 Patient_0015 Driver-negative Adenocarcinoma test
# 839 Patient_0017 Driver-negative Adenocarcinoma train
# 840 Patient_0019 Driver-positive Adenocarcinoma independent
# 841 Patient_0021 Driver-positive Adenocarcinoma independent
# 842 Patient_0023 Driver-positive Adenocarcinoma independent
# 843 Patient_0024 Driver-negative Adenocarcinoma train
# 844 Patient_0026 Driver-positive Squamous cell carcinoma independent
# 845 Patient_0027 Driver-negative Non-small cell carcinoma NOS train
# 846 Patient_0028 Driver-negative Adenocarcinoma train
# ...

# %%
df_train
# Out:
#                       ID                Histology Histology012
# 0         Hugo_LUNG1-001               large cell            2
# 1         Hugo_LUNG1-002  squamous cell carcinoma            1
# 2         Hugo_LUNG1-003               large cell            2
# 3         Hugo_LUNG1-004  squamous cell carcinoma            1
# 4         Hugo_LUNG1-005  squamous cell carcinoma            1
# ..                   ...                      ...          ...
# 487  NSCLC_Hugo_89_pt_83           adenocarcinoma            0
# 488  NSCLC_Hugo_89_pt_84           adenocarcinoma            0
# 489  NSCLC_Hugo_89_pt_85           adenocarcinoma            0
# 490  NSCLC_Hugo_89_pt_86                      nos            2
# 491  NSCLC_Hugo_89_pt_89                      nos            2
#
# [492 rows x 3 columns]

# %% [markdown]
# ## Only Nature 2

# %%
train_folder = 'E:/data/Histology/Nature_4D_Organized/TrainValTest/OnlyNature2'
val_folder =   'E:/data/Histology/Nature_4D_Organized/TrainValTest/OnlyNature2'
test_folder =  'E:/data/Histology/Nature_4D_Organized/TrainValTest/OnlyNature2'
os.makedirs(train_folder, exist_ok=True)
os.makedirs(val_folder, exist_ok=True)
os.makedirs(test_folder, exist_ok=True)


nature_train = ['TCGA LUAD/LUSC','NSCLC Radiomics','NSCLC Radiomics-Genomics']
nature_val = ['Stanford','NSCLC Radiogenomics']
nature_test = [] #['NSCLC Radiogenomics'] #Sandys


df = pd.read_csv('both.csv')
df_train = pd.DataFrame(columns=['ID', 'Histology','Histology012'])
df_val   = pd.DataFrame(columns=['ID', 'Histology','Histology012'])
df_test  = pd.DataFrame(columns=['ID', 'Histology','Histology012'])

D = {'adenocarcinoma'              : 1 ,
     'Adenocarcinoma'              : 1 ,
     'Squamous cell carcinoma'     : 0 ,
     'squamous cell carcinoma'     : 0 ,
     'Sarcomatoid carcinoma'       : 1 ,
     'Adenosquamous carcinoma'     : 1 ,
     'Large cell carcinoma'        : 1 ,
     'Non-small cell carcinoma NOS': 1 ,
     'Sarcomatoid carcinoma'       : 1 ,
     'large cell'                  : 1 ,
     'nos'                         : 1 }

for i, id in enumerate(df['ID'].tolist()):
    id_i,patient_i,dataset_i, histology_i,_,Cohort_i = df.iloc[i].tolist()
    
    if dataset_i in nature_train:
        df_train = df_train.append([pd.Series([patient_i, histology_i, D[histology_i]], index = df_train.columns[0:3])], ignore_index=True)
        
    elif dataset_i in nature_val:
        df_val = df_val.append([pd.Series([patient_i, histology_i, D[histology_i]], index = df_val.columns[0:3])], ignore_index=True)

    elif dataset_i in nature_test:
        df_test = df_test.append([pd.Series([patient_i, histology_i, D[histology_i]], index = df_test.columns[0:3])], ignore_index=True)
        
    else:
        print(id_i,patient_i,dataset_i, histology_i,Cohort_i)
df_train.to_csv(os.path.join(train_folder, 'train.csv'))
df_val.to_csv(os.path.join(val_folder, 'val.csv'))
df_test.to_csv(os.path.join(test_folder, 'test.csv'))
df_train
# Out:
# 831 Patient_0002 Driver-negative Adenocarcinoma train
# 832 Patient_0007 Driver-negative Adenocarcinoma train
# 833 Patient_0008 Driver-negative Adenocarcinoma train
# 834 Patient_0009 Driver-negative Adenocarcinoma train
# 835 Patient_0010 Driver-negative Adenocarcinoma test
# 836 Patient_0011 Driver-negative Adenocarcinoma train
# 837 Patient_0012 Driver-negative Adenocarcinoma train
# 838 Patient_0015 Driver-negative Adenocarcinoma test
# 839 Patient_0017 Driver-negative Adenocarcinoma train
# 840 Patient_0019 Driver-positive Adenocarcinoma independent
# 841 Patient_0021 Driver-positive Adenocarcinoma independent
# 842 Patient_0023 Driver-positive Adenocarcinoma independent
# 843 Patient_0024 Driver-negative Adenocarcinoma train
# 844 Patient_0026 Driver-positive Squamous cell carcinoma independent
# 845 Patient_0027 Driver-negative Non-small cell carcinoma NOS train
# 846 Patient_0028 Driver-negative Adenocarcinoma train
# ...

# %% [markdown]
# ## Only GEMINI 3

# %%
train_folder = 'E:/data/Histology/Nature_4D_Organized/TrainValTest/OnlyGemini3'
val_folder =   'E:/data/Histology/Nature_4D_Organized/TrainValTest/OnlyGemini3'
test_folder =  'E:/data/Histology/Nature_4D_Organized/TrainValTest/OnlyGemini3'
os.makedirs(train_folder, exist_ok=True)
os.makedirs(val_folder, exist_ok=True)
os.makedirs(test_folder, exist_ok=True)


nature_train = ['TCGA LUAD/LUSC','NSCLC Radiomics','NSCLC Radiomics-Genomics']
nature_val = ['Stanford','NSCLC Radiogenomics']
nature_test = [] #['NSCLC Radiogenomics'] #Sandys

df = pd.read_csv('both.csv')
df_train = pd.DataFrame(columns=['ID', 'Histology','Histology012'])
df_val   = pd.DataFrame(columns=['ID', 'Histology','Histology012'])
df_test  = pd.DataFrame(columns=['ID', 'Histology','Histology012'])

D = {'adenocarcinoma'              : 0 ,
     'Adenocarcinoma'              : 0 ,
     'Squamous cell carcinoma'     : 1 ,
     'squamous cell carcinoma'     : 1 ,
     'Sarcomatoid carcinoma'       : 2 ,
     'Adenosquamous carcinoma'     : 2 ,
     'Large cell carcinoma'        : 2 ,
     'Non-small cell carcinoma NOS': 2 ,
     'Sarcomatoid carcinoma'       : 2 ,
     'large cell'                  : 2 ,
     'nos'                         : 2 }

for i, id in enumerate(df['ID'].tolist()):
    id_i,patient_i,dataset_i, histology_i,_,Cohort_i = df.iloc[i].tolist()
    
    if Cohort_i == 'train' or Cohort_i == 'independent':
        df_train = df_train.append([pd.Series([patient_i, histology_i, D[histology_i]], index = df_train.columns[0:3])], ignore_index=True)
        
    elif Cohort_i == 'valid':
        df_val = df_val.append([pd.Series([patient_i, histology_i, D[histology_i]], index = df_val.columns[0:3])], ignore_index=True)

    elif Cohort_i == 'test':
        df_test = df_test.append([pd.Series([patient_i, histology_i, D[histology_i]], index = df_test.columns[0:3])], ignore_index=True)
        
    else:
        print(id_i,patient_i,dataset_i, histology_i,Cohort_i)
df_train.to_csv(os.path.join(train_folder, 'train.csv'))
df_val.to_csv(os.path.join(val_folder, 'val.csv'))
df_test.to_csv(os.path.join(test_folder, 'test.csv'))
# Out:
# 0 Hugo_LUNG1-001 NSCLC Radiomics large cell nan
# 1 Hugo_LUNG1-002 NSCLC Radiomics squamous cell carcinoma nan
# 2 Hugo_LUNG1-003 NSCLC Radiomics large cell nan
# 3 Hugo_LUNG1-004 NSCLC Radiomics squamous cell carcinoma nan
# 4 Hugo_LUNG1-005 NSCLC Radiomics squamous cell carcinoma nan
# 5 Hugo_LUNG1-006 NSCLC Radiomics squamous cell carcinoma nan
# 6 Hugo_LUNG1-007 NSCLC Radiomics squamous cell carcinoma nan
# 7 Hugo_LUNG1-008 NSCLC Radiomics adenocarcinoma nan
# 8 Hugo_LUNG1-009 NSCLC Radiomics squamous cell carcinoma nan
# 9 Hugo_LUNG1-010 NSCLC Radiomics squamous cell carcinoma nan
# 10 Hugo_LUNG1-011 NSCLC Radiomics squamous cell carcinoma nan
# 11 Hugo_LUNG1-012 NSCLC Radiomics squamous cell carcinoma nan
# 12 Hugo_LUNG1-013 NSCLC Radiomics nos nan
# 13 Hugo_LUNG1-015 NSCLC Radiomics large cell nan
# 14 Hugo_LUNG1-016 NSCLC Radiomics nos nan
# 15 Hugo_LUNG1-017 NSCLC Radiomics large cell nan
# 16 Hugo_LUNG1-018 NSCLC Radiomics squamous cell carcinoma nan
# ...

# %%
df_val
# Out:
#               ID                     Histology Histology012
# 0   Patient_0041                Adenocarcinoma            0
# 1   Patient_0048                Adenocarcinoma            0
# 2   Patient_0054                Adenocarcinoma            0
# 3   Patient_0071                Adenocarcinoma            0
# 4   Patient_0091                Adenocarcinoma            0
# ..           ...                           ...          ...
# 73  Patient_1226                Adenocarcinoma            0
# 74  Patient_1228                Adenocarcinoma            0
# 75  Patient_1232  Non-small cell carcinoma NOS            2
# 76  Patient_1267       Squamous cell carcinoma            1
# 77  Patient_1272                Adenocarcinoma            0
#
# [78 rows x 3 columns]

# %% [markdown]
# ## Only GEMINI 2

# %%
train_folder = 'E:/data/Histology/Nature_4D_Organized/TrainValTest/OnlyGemini2'
val_folder =   'E:/data/Histology/Nature_4D_Organized/TrainValTest/OnlyGemini2'
test_folder =  'E:/data/Histology/Nature_4D_Organized/TrainValTest/OnlyGemini2'
os.makedirs(train_folder, exist_ok=True)
os.makedirs(val_folder, exist_ok=True)
os.makedirs(test_folder, exist_ok=True)


nature_train = ['TCGA LUAD/LUSC','NSCLC Radiomics','NSCLC Radiomics-Genomics']
nature_val = ['Stanford','NSCLC Radiogenomics']
nature_test = [] #['NSCLC Radiogenomics'] #Sandys

df = pd.read_csv('both.csv')
df_train = pd.DataFrame(columns=['ID', 'Histology','Histology012'])
df_val   = pd.DataFrame(columns=['ID', 'Histology','Histology012'])
df_test  = pd.DataFrame(columns=['ID', 'Histology','Histology012'])

D = {'adenocarcinoma'              : 1 ,
     'Adenocarcinoma'              : 1 ,
     'Squamous cell carcinoma'     : 0 ,
     'squamous cell carcinoma'     : 0 ,
     'Sarcomatoid carcinoma'       : 1 ,
     'Adenosquamous carcinoma'     : 1 ,
     'Large cell carcinoma'        : 1 ,
     'Non-small cell carcinoma NOS': 1 ,
     'Sarcomatoid carcinoma'       : 1 ,
     'large cell'                  : 1 ,
     'nos'                         : 1 }

for i, id in enumerate(df['ID'].tolist()):
    id_i,patient_i,dataset_i, histology_i,_,Cohort_i = df.iloc[i].tolist()
    
    if Cohort_i == 'train' or Cohort_i == 'independent':
        df_train = df_train.append([pd.Series([patient_i, histology_i, D[histology_i]], index = df_train.columns[0:3])], ignore_index=True)
        
    elif Cohort_i == 'valid':
        df_val = df_val.append([pd.Series([patient_i, histology_i, D[histology_i]], index = df_val.columns[0:3])], ignore_index=True)

    elif Cohort_i == 'test':
        df_test = df_test.append([pd.Series([patient_i, histology_i, D[histology_i]], index = df_test.columns[0:3])], ignore_index=True)
        
    else:
        print(id_i,patient_i,dataset_i, histology_i,Cohort_i)
df_train.to_csv(os.path.join(train_folder, 'train.csv'))
df_val.to_csv(os.path.join(val_folder, 'val.csv'))
df_test.to_csv(os.path.join(test_folder, 'test.csv'))
# Out:
# 0 Hugo_LUNG1-001 NSCLC Radiomics large cell nan
# 1 Hugo_LUNG1-002 NSCLC Radiomics squamous cell carcinoma nan
# 2 Hugo_LUNG1-003 NSCLC Radiomics large cell nan
# 3 Hugo_LUNG1-004 NSCLC Radiomics squamous cell carcinoma nan
# 4 Hugo_LUNG1-005 NSCLC Radiomics squamous cell carcinoma nan
# 5 Hugo_LUNG1-006 NSCLC Radiomics squamous cell carcinoma nan
# 6 Hugo_LUNG1-007 NSCLC Radiomics squamous cell carcinoma nan
# 7 Hugo_LUNG1-008 NSCLC Radiomics adenocarcinoma nan
# 8 Hugo_LUNG1-009 NSCLC Radiomics squamous cell carcinoma nan
# 9 Hugo_LUNG1-010 NSCLC Radiomics squamous cell carcinoma nan
# 10 Hugo_LUNG1-011 NSCLC Radiomics squamous cell carcinoma nan
# 11 Hugo_LUNG1-012 NSCLC Radiomics squamous cell carcinoma nan
# 12 Hugo_LUNG1-013 NSCLC Radiomics nos nan
# 13 Hugo_LUNG1-015 NSCLC Radiomics large cell nan
# 14 Hugo_LUNG1-016 NSCLC Radiomics nos nan
# 15 Hugo_LUNG1-017 NSCLC Radiomics large cell nan
# 16 Hugo_LUNG1-018 NSCLC Radiomics squamous cell carcinoma nan
# ...

# %%
df_train
# Out:
#                ID                Histology Histology012
# 0    Patient_0002           Adenocarcinoma            1
# 1    Patient_0007           Adenocarcinoma            1
# 2    Patient_0008           Adenocarcinoma            1
# 3    Patient_0009           Adenocarcinoma            1
# 4    Patient_0011           Adenocarcinoma            1
# ..            ...                      ...          ...
# 769  Patient_1290           Adenocarcinoma            1
# 770  Patient_1292           Adenocarcinoma            1
# 771  Patient_1293           Adenocarcinoma            1
# 772  Patient_1295  Squamous cell carcinoma            0
# 773  Patient_1298           Adenocarcinoma            1
#
# [774 rows x 3 columns]

# %% [markdown]
# {'Stanford':'val', 'NSCLC Radiogenomics':'test, 'TCGA LUAD/LUSC':'train', 'NSCLC Radiomics':'train', 'NSCLC Radiomics-Genomics':'train}
#
# Nature NSCLC Radiogenomics
# ..............................
# nos : 3
# adenocarcinoma : 164
# large cell : 0
# squamous cell carcinoma : 31
#
# ####################################
#
# Nature NSCLC Radiomics-Genomics
# ..............................
# nos : 33
# adenocarcinoma : 41
# large cell : 1
# squamous cell carcinoma : 0
#
# ####################################
#
# Nature Stanford
# ..............................
# nos : 0
# adenocarcinoma : 84
# large cell : 4
# squamous cell carcinoma : 53
#
# ####################################
#
# Nature TCGA LUAD/LUSC
# ..............................
# nos : 0
# adenocarcinoma : 60
# large cell : 0
# squamous cell carcinoma : 34
#
# ####################################
#
# Nature NSCLC Radiomics
# ..............................
# nos : 54
# adenocarcinoma : 43
# large cell : 97
# squamous cell carcinoma : 129

# %%
print(set(df['Cohort']))
print(df.columns)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\MSALEH~1\ONEDRI~1.ORG\DOCUME~1\MOBAXT~1\slash\tmp/ipykernel_21260/2451997806.py in <module>
# ----> 1 print(set(df['Cohort']))
#       2 print(df.columns)
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## Nature Gemini 3

# %%
train_folder = 'E:/data/Histology/Nature_4D_Organized/TrainValTest/NatureGemini3'
val_folder =   'E:/data/Histology/Nature_4D_Organized/TrainValTest/NatureGemini3'
test_folder =  'E:/data/Histology/Nature_4D_Organized/TrainValTest/NatureGemini3'
os.makedirs(train_folder, exist_ok=True)
os.makedirs(val_folder, exist_ok=True)
os.makedirs(test_folder, exist_ok=True)


nature_train = ['TCGA LUAD/LUSC','NSCLC Radiomics','NSCLC Radiomics-Genomics']
nature_val = ['Stanford','NSCLC Radiogenomics']
nature_test = [] #['NSCLC Radiogenomics'] #Sandys

df = pd.read_csv('both.csv')
df_train = pd.DataFrame(columns=['ID', 'Histology','Histology012'])
df_val   = pd.DataFrame(columns=['ID', 'Histology','Histology012'])
df_test  = pd.DataFrame(columns=['ID', 'Histology','Histology012'])

D = {'adenocarcinoma'              : 0 ,
     'Adenocarcinoma'              : 0 ,
     'Squamous cell carcinoma'     : 1 ,
     'squamous cell carcinoma'     : 1 ,
     'Sarcomatoid carcinoma'       : 2 ,
     'Adenosquamous carcinoma'     : 2 ,
     'Large cell carcinoma'        : 2 ,
     'Non-small cell carcinoma NOS': 2 ,
     'Sarcomatoid carcinoma'       : 2 ,
     'large cell'                  : 2 ,
     'nos'                         : 2 }

for i, id in enumerate(df['ID'].tolist()):
    id_i,patient_i,dataset_i, histology_i,_,Cohort_i = df.iloc[i].tolist()
    
    if Cohort_i == 'train' or Cohort_i == 'independent' or dataset_i in nature_train:
        df_train = df_train.append([pd.Series([patient_i, histology_i, D[histology_i]], index = df_train.columns[0:3])], ignore_index=True)
        
    elif Cohort_i == 'valid'  or dataset_i in nature_val:
        df_val = df_val.append([pd.Series([patient_i, histology_i, D[histology_i]], index = df_val.columns[0:3])], ignore_index=True)

    elif Cohort_i == 'test'  or dataset_i in nature_test:
        df_test = df_test.append([pd.Series([patient_i, histology_i, D[histology_i]], index = df_test.columns[0:3])], ignore_index=True)
        
    else:
        print(id_i,patient_i,dataset_i, histology_i,Cohort_i)
df_train.to_csv(os.path.join(train_folder, 'train.csv'))
df_val.to_csv(os.path.join(val_folder, 'val.csv'))
df_test.to_csv(os.path.join(test_folder, 'test.csv'))

# %%
df_train
# Out:
#                   ID                Histology Histology012
# 0     Hugo_LUNG1-001               large cell            2
# 1     Hugo_LUNG1-002  squamous cell carcinoma            1
# 2     Hugo_LUNG1-003               large cell            2
# 3     Hugo_LUNG1-004  squamous cell carcinoma            1
# 4     Hugo_LUNG1-005  squamous cell carcinoma            1
# ...              ...                      ...          ...
# 1261    Patient_1290           Adenocarcinoma            0
# 1262    Patient_1292           Adenocarcinoma            0
# 1263    Patient_1293           Adenocarcinoma            0
# 1264    Patient_1295  Squamous cell carcinoma            1
# 1265    Patient_1298           Adenocarcinoma            0
#
# [1266 rows x 3 columns]

# %% [markdown]
# # NatureGemini 2

# %%
train_folder = 'E:/data/Histology/Nature_4D_Organized/TrainValTest/NatureGemini2'
val_folder =   'E:/data/Histology/Nature_4D_Organized/TrainValTest/NatureGemini2'
test_folder =  'E:/data/Histology/Nature_4D_Organized/TrainValTest/NatureGemini2'
os.makedirs(train_folder, exist_ok=True)
os.makedirs(val_folder, exist_ok=True)
os.makedirs(test_folder, exist_ok=True)


nature_train = ['TCGA LUAD/LUSC','NSCLC Radiomics','NSCLC Radiomics-Genomics']
nature_val = ['Stanford','NSCLC Radiogenomics']
nature_test = [] #['NSCLC Radiogenomics'] #Sandys

df = pd.read_csv('both.csv')
df_train = pd.DataFrame(columns=['ID', 'Histology','Histology012'])
df_val   = pd.DataFrame(columns=['ID', 'Histology','Histology012'])
df_test  = pd.DataFrame(columns=['ID', 'Histology','Histology012'])

D = {'adenocarcinoma'              : 1 ,
     'Adenocarcinoma'              : 1 ,
     'Squamous cell carcinoma'     : 0 ,
     'squamous cell carcinoma'     : 0 ,
     'Sarcomatoid carcinoma'       : 1 ,
     'Adenosquamous carcinoma'     : 1 ,
     'Large cell carcinoma'        : 1 ,
     'Non-small cell carcinoma NOS': 1 ,
     'Sarcomatoid carcinoma'       : 1 ,
     'large cell'                  : 1 ,
     'nos'                         : 1 }

for i, id in enumerate(df['ID'].tolist()):
    id_i,patient_i,dataset_i, histology_i,_,Cohort_i = df.iloc[i].tolist()
    
    if Cohort_i == 'train' or Cohort_i == 'independent' or dataset_i in nature_train:
        df_train = df_train.append([pd.Series([patient_i, histology_i, D[histology_i]], index = df_train.columns[0:3])], ignore_index=True)
        
    elif Cohort_i == 'valid'  or dataset_i in nature_val:
        df_val = df_val.append([pd.Series([patient_i, histology_i, D[histology_i]], index = df_val.columns[0:3])], ignore_index=True)

    elif Cohort_i == 'test'  or dataset_i in nature_test:
        df_test = df_test.append([pd.Series([patient_i, histology_i, D[histology_i]], index = df_test.columns[0:3])], ignore_index=True)
        
    else:
        print(id_i,patient_i,dataset_i, histology_i,Cohort_i)
df_train.to_csv(os.path.join(train_folder, 'train.csv'))
df_val.to_csv(os.path.join(val_folder, 'val.csv'))
df_test.to_csv(os.path.join(test_folder, 'test.csv'))

# %%
df_train
# Out:
#                   ID                Histology Histology012
# 0     Hugo_LUNG1-001               large cell            1
# 1     Hugo_LUNG1-002  squamous cell carcinoma            0
# 2     Hugo_LUNG1-003               large cell            1
# 3     Hugo_LUNG1-004  squamous cell carcinoma            0
# 4     Hugo_LUNG1-005  squamous cell carcinoma            0
# ...              ...                      ...          ...
# 1261    Patient_1290           Adenocarcinoma            1
# 1262    Patient_1292           Adenocarcinoma            1
# 1263    Patient_1293           Adenocarcinoma            1
# 1264    Patient_1295  Squamous cell carcinoma            0
# 1265    Patient_1298           Adenocarcinoma            1
#
# [1266 rows x 3 columns]

# %%
print('##### TRAINING ######')
print("'''''''''''''''''''''")
print('Adeno    : ',df_train[df_train['Histology012']==0].shape[0])
print('Squamous : ',df_train[df_train['Histology012']==1].shape[0])
print('other    : ',df_train[df_train['Histology012']==2].shape[0])
print()
print()
print('##### Validation ######')
print("'''''''''''''''''''''")
print('Adeno    : ',df_val[df_val['Histology012']==0].shape[0])
print('Squamous : ',df_val[df_val['Histology012']==1].shape[0])
print('other    : ',df_val[df_val['Histology012']==2].shape[0])
print()
print()
print('##### Test ######')
print("'''''''''''''''''''''")
print('Adeno    : ',df_test[df_test['Histology012']==0].shape[0])
print('Squamous : ',df_test[df_test['Histology012']==1].shape[0])
print('other    : ',df_test[df_test['Histology012']==2].shape[0])

# %%
df_train

# %%
df_val

# %%
df_test

# %%
df.shape[0] =

# %%
1266 + 417+ 278

# %% [markdown]
# ## Renaming

# %%
path = 'E:/data/Histology/Nature_4D_Organized/TrainValTest/GEMINI_Nature'

for file in os.listdir(path):
    
    if file.endswith('_ct.nii.gz'):
        file_cor = file[:-10]
        source = os.path.join(path, file)
        des = os.path.join(path, file_cor+'.nii.gz')
        os.rename(source, des)
        print(file_cor)

# %%
def MultiLabel_Acc(Pred,Y):
    acc = None
    for i in range(len(Y[1,:])):
        if i == 0:
            acc = accuracy_score(Y[:,i],Pred[:,i])
        else:
            acc = np.concatenate((acc,accuracy_score(Y[:,i],Pred[:,i])),axis=None)

    return(acc)

# %%
Pred= [0,1,2]
Y = [0,1,2]
